# %% [markdown]
# # Clean up
#
# To clean up, we need only remove our Feature Store instance and tear down out PostgreSQL database.

# %%
# !oc delete -f feast.yaml --wait
# !oc delete -f postgres.yaml --wait
